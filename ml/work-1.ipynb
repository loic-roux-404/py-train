# %%
import numpy as np
import pandas as pd
from os import path

# %%
csv_loc = path.expanduser('~/Documents/Ia-Datasets/en.openfoodfacts.org.products.tsv')
food = pd.read_csv(csv_loc, sep='\t', low_memory=False)

# %%
food.head(20)
# Out:
#              code                                                url  \
# 0   0000000003087  http://world-en.openfoodfacts.org/product/0000...
# 1   0000000004530  http://world-en.openfoodfacts.org/product/0000...
# 2   0000000004559  http://world-en.openfoodfacts.org/product/0000...
# 3   0000000016087  http://world-en.openfoodfacts.org/product/0000...
# 4   0000000016094  http://world-en.openfoodfacts.org/product/0000...
# 5   0000000016100  http://world-en.openfoodfacts.org/product/0000...
# 6   0000000016117  http://world-en.openfoodfacts.org/product/0000...
# 7   0000000016124  http://world-en.openfoodfacts.org/product/0000...
# 8   0000000016193  http://world-en.openfoodfacts.org/product/0000...
# 9   0000000016513  http://world-en.openfoodfacts.org/product/0000...
# 10  0000000016612  http://world-en.openfoodfacts.org/product/0000...
# 11  0000000016650  http://world-en.openfoodfacts.org/product/0000...
# 12  0000000016872  http://world-en.openfoodfacts.org/product/0000...
# ...

# %%
# get name of column 105
food.columns[104]
# Out:
# '-glucose_100g'

# %%
food.dtypes[food.columns[104]]
# Out:
# dtype('float64')

# %%
food.values[18][7]
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %% [markdown]
# Activité 2 & 6

# %%
users = pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep="|", index_col="user_id")

# %%
users.tail(10)
# Out:
#          age gender     occupation zip_code
# user_id
# 934       61      M       engineer    22902
# 935       42      M         doctor    66221
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 938       38      F     technician    55038
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 943 entries, 1 to 943
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         943 non-null    int64
#  1   gender      943 non-null    object
#  2   occupation  943 non-null    object
#  3   zip_code    943 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 36.8+ KB

# %%
users.occupation.nunique()
# Out:
# 21

# %%
users.occupation.value_counts()
# Out:
# occupation
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: count, dtype: int64

# %%
users.describe(include='all')
# Out:
#                age gender occupation zip_code
# count   943.000000    943        943      943
# unique         NaN      2         21      795
# top            NaN      M    student    55414
# freq           NaN    670        196        9
# mean     34.051962    NaN        NaN      NaN
# std      12.192740    NaN        NaN      NaN
# min       7.000000    NaN        NaN      NaN
# 25%      25.000000    NaN        NaN      NaN
# 50%      31.000000    NaN        NaN      NaN
# 75%      43.000000    NaN        NaN      NaN
# max      73.000000    NaN        NaN      NaN

# %%
round(users.age.mean(), 1)
# Out:
# 34.1

# %%
users.age.median()
# Out:
# 31.0

# %%
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
users['genre_numerique'] = users.gender.apply(lambda x: 1 if x == 'M' else 0)

# %%
# sum only take > 0 values so womans are excluded from subject data
percent = users.groupby('occupation').genre_numerique.sum() / users.occupation.value_counts() * 100

percent
# Out:
# occupation
# administrator     54.430380
# artist            53.571429
# doctor           100.000000
# educator          72.631579
# engineer          97.014925
# entertainment     88.888889
# executive         90.625000
# healthcare        31.250000
# homemaker         14.285714
# lawyer            83.333333
# librarian         43.137255
# marketing         61.538462
# none              55.555556
# other             65.714286
# programmer        90.909091
# retired           92.857143
# salesman          75.000000
# scientist         90.322581
# student           69.387755
# technician        96.296296
# writer            57.777778
# dtype: float64

# %%
percent.sort_values(ascending=False)
# Out:
# occupation
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# dtype: float64

# %%
round(users.groupby(['gender', 'occupation']).age.agg(['min', 'mean', 'max']))
# Out:
#                       min  mean  max
# gender occupation
# F      administrator   22  41.0   62
#        artist          19  30.0   48
#        educator        23  39.0   51
#        engineer        23  30.0   36
#        entertainment   24  31.0   38
#        executive       39  44.0   49
#        healthcare      22  40.0   53
#        homemaker       20  34.0   50
#        lawyer          28  40.0   51
#        librarian       26  40.0   59
#        marketing       24  37.0   50
#        none            26  36.0   55
#        other           18  35.0   55
#        programmer      26  32.0   38
#        retired         70  70.0   70
#        salesman        18  27.0   33
#        scientist       26  28.0   31
#        student         13  21.0   38
#        technician      38  38.0   38
#        writer          18  38.0   56
# M      administrator   21  37.0   70
#        artist          20  32.0   45
#        doctor          28  44.0   64
#        educator        25  43.0   63
# ...

# %%
users.iloc[10:30, 2] = np.nan

users.head(30)

users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 943 entries, 1 to 943
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              943 non-null    int64
#  1   gender           943 non-null    object
#  2   occupation       923 non-null    object
#  3   zip_code         943 non-null    object
#  4   genre_numerique  943 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 44.2+ KB

# %%
users.isnull().sum()
