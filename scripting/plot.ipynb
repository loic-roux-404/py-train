# %%
import math
import numpy
import matplotlib.pyplot as plt

# %%
x_max = 5
y_max = 5
y_min = 0
x_min = 0

# %%
x = numpy.linspace(x_max, x_min)
y = numpy.linspace(y_max, y_min)

# %%
plt.plot(x, y)
plt.show()
